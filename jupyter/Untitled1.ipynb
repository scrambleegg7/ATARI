# %%
import gym
import numpy as np
env = gym.make("MountainCar-v0")

class Tilecoder:

    def __init__(self, numTilings, tilesPerTiling):
        # Set max value for normalization of inputs
        self.maxNormal = 1
        self.maxVal = env.observation_space.high
        self.minVal = env.observation_space.low
        self.numTilings = numTilings
        self.tilesPerTiling = tilesPerTiling
        self.dim = len(self.maxVal)
        self.numTiles = (self.tilesPerTiling**self.dim) * self.numTilings
        self.actions = env.action_space.n
        self.n = self.numTiles * self.actions
        self.tileSize = np.divide(np.ones(self.dim)*self.maxNormal, self.tilesPerTiling-1)

    def getFeatures(self, variables):
        # Ensures range is always between 0 and self.maxValue
        values = np.zeros(self.dim)
        for i in range(len(env.observation_space.shape)+1):
            values[i] = self.maxNormal * ((variables[i] - self.minVal[i])/(self.maxVal[i]-self.minVal[i]))
        tileIndices = np.zeros(self.numTilings)
        matrix = np.zeros([self.numTilings,self.dim])
        for i in range(self.numTilings):
            for i2 in range(self.dim):
                matrix[i,i2] = int(values[i2] / self.tileSize[i2] + i / self.numTilings)
        for i in range(1,self.dim):
            matrix[:,i] *= self.tilesPerTiling**i
        for i in range(self.numTilings):
            tileIndices[i] = (i * (self.tilesPerTiling**self.dim) + sum(matrix[i,:])) 
        return tileIndices

    def oneHotVector(self, features, action):
        oneHot = np.zeros(self.n)
        for i in features:
            index = int(i + (self.numTiles*action))
            oneHot[index] = 1
        return oneHot

    def getVal(self, theta, features, action):
        val = 0 
        for i in features:
            index = int(i + (self.numTiles*action))
            val += theta[index]
        return val

    def getQ(self, features, theta):
        Q = np.zeros(self.actions)
        for i in range(self.actions):
            Q[i] = tile.getVal(theta, features, i)
        return Q


if __name__ == "__main__":

    tile = Tilecoder(7,14)
    theta = np.random.uniform(-0.001, 0, size=(tile.n))
    alpha = (.1/ tile.numTilings)*3.2
    gamma = 1
    numEpisodes = 100000
    rewardTracker = []
    episodeSum = 0
    counter = 0 

    for episodeNum in range(1,numEpisodes+1):
        G = 0
        state = env.reset()
        while True:
            #env.render()
            F = tile.getFeatures(state)
            Q = tile.getQ(F, theta)
            action = np.argmax(Q)
            state2, reward, done, info = env.step(action)
            G += reward
            delta = reward - Q[action]
            print("accumulated reward {}".format(G))
            if done == True:
                theta += np.multiply((alpha*delta), tile.oneHotVector(F,action))
                episodeSum += G
                rewardTracker.append(G)
                if episodeNum %100 == 0:
                    print('Average reward = {}'.format(episodeSum / 100))
                    episodeSum = 0
                break
            Q = tile.getQ(tile.getFeatures(state2), theta)
            delta += gamma*np.max(Q)
            theta += np.multiply((alpha*delta), tile.oneHotVector(F,action))
            state = state2

        if episodeNum > 100:
            if sum(rewardTracker[episodeNum-100:episodeNum])/100 >= -110:
                print('Solve in {} Episodes'.format(episodeNum))
break
# Out:
# [2017-11-23 15:51:17,492] Making new env: MountainCar-v0
# accumulated reward -1.0
# accumulated reward -2.0
# accumulated reward -3.0
# accumulated reward -4.0
# accumulated reward -5.0
# accumulated reward -6.0
# accumulated reward -7.0
# accumulated reward -8.0
# accumulated reward -9.0
# accumulated reward -10.0
# accumulated reward -11.0
# accumulated reward -12.0
# accumulated reward -13.0
# accumulated reward -14.0
# accumulated reward -15.0
# accumulated reward -16.0
# accumulated reward -17.0
# accumulated reward -18.0
# accumulated reward -19.0
# accumulated reward -20.0
# accumulated reward -21.0
# accumulated reward -22.0
# accumulated reward -23.0
# accumulated reward -24.0
# accumulated reward -25.0
# accumulated reward -26.0
# accumulated reward -27.0
# accumulated reward -28.0
# accumulated reward -29.0
# accumulated reward -30.0
# accumulated reward -31.0
# accumulated reward -32.0
# accumulated reward -33.0
# accumulated reward -34.0
# accumulated reward -35.0
# accumulated reward -36.0
# accumulated reward -37.0
# accumulated reward -38.0
# accumulated reward -39.0
# accumulated reward -40.0
# accumulated reward -41.0
# accumulated reward -42.0
# accumulated reward -43.0
# accumulated reward -44.0
# accumulated reward -45.0
# accumulated reward -46.0
# accumulated reward -47.0
# accumulated reward -48.0
# accumulated reward -49.0
# accumulated reward -50.0
# accumulated reward -51.0
# accumulated reward -52.0
# accumulated reward -53.0
# accumulated reward -54.0
# accumulated reward -55.0
# accumulated reward -56.0
# accumulated reward -57.0
# accumulated reward -58.0
# accumulated reward -59.0
# accumulated reward -60.0
# accumulated reward -61.0
# accumulated reward -62.0
# accumulated reward -63.0
# accumulated reward -64.0
# accumulated reward -65.0
# accumulated reward -66.0
# accumulated reward -67.0
# accumulated reward -68.0
# accumulated reward -69.0
# accumulated reward -70.0
# accumulated reward -71.0
# accumulated reward -72.0
# accumulated reward -73.0
# accumulated reward -74.0
# accumulated reward -75.0
# accumulated reward -76.0
# accumulated reward -77.0
# accumulated reward -78.0
# accumulated reward -79.0
# accumulated reward -80.0
# accumulated reward -81.0
# accumulated reward -82.0
# accumulated reward -83.0
# accumulated reward -84.0
# accumulated reward -85.0
# accumulated reward -86.0
# accumulated reward -87.0
# accumulated reward -88.0
# accumulated reward -89.0
# accumulated reward -90.0
# accumulated reward -91.0
# accumulated reward -92.0
# accumulated reward -93.0
# accumulated reward -94.0
# accumulated reward -95.0
# accumulated reward -96.0
# accumulated reward -97.0
# accumulated reward -98.0
# accumulated reward -99.0
# accumulated reward -100.0
# accumulated reward -101.0
# accumulated reward -102.0
# accumulated reward -103.0
# accumulated reward -104.0
# accumulated reward -105.0
# accumulated reward -106.0
# accumulated reward -107.0
# accumulated reward -108.0
# accumulated reward -109.0
# accumulated reward -110.0
# accumulated reward -111.0
# accumulated reward -112.0
# accumulated reward -113.0
# accumulated reward -114.0
# accumulated reward -115.0
# accumulated reward -116.0
# accumulated reward -117.0
# accumulated reward -118.0
# accumulated reward -119.0
# accumulated reward -120.0
# accumulated reward -121.0
# accumulated reward -122.0
# accumulated reward -123.0
# accumulated reward -124.0
# accumulated reward -125.0
# accumulated reward -126.0
# accumulated reward -127.0
# accumulated reward -128.0
# accumulated reward -129.0
# accumulated reward -130.0
# accumulated reward -131.0
# accumulated reward -132.0
# accumulated reward -133.0
# accumulated reward -134.0
# accumulated reward -135.0
# accumulated reward -136.0
# accumulated reward -137.0
# accumulated reward -138.0
# accumulated reward -139.0
# accumulated reward -140.0
# accumulated reward -141.0
# accumulated reward -142.0
# accumulated reward -143.0
# accumulated reward -144.0
# accumulated reward -145.0
# accumulated reward -146.0
# accumulated reward -147.0
# accumulated reward -148.0
# accumulated reward -149.0
# accumulated reward -150.0
# accumulated reward -151.0
# accumulated reward -152.0
# accumulated reward -153.0
# accumulated reward -154.0
# accumulated reward -155.0
# accumulated reward -156.0
# accumulated reward -157.0
# accumulated reward -158.0
# accumulated reward -159.0
# accumulated reward -160.0
# accumulated reward -161.0
# accumulated reward -162.0
# accumulated reward -163.0
# accumulated reward -164.0
# accumulated reward -165.0
# accumulated reward -166.0
# accumulated reward -167.0
# accumulated reward -168.0
# accumulated reward -169.0
# accumulated reward -170.0
# accumulated reward -171.0
# accumulated reward -172.0
# accumulated reward -173.0
# accumulated reward -174.0
# accumulated reward -175.0
# accumulated reward -176.0
# accumulated reward -177.0
# accumulated reward -178.0
# accumulated reward -179.0
# accumulated reward -180.0
# accumulated reward -181.0
# accumulated reward -182.0
# accumulated reward -183.0
# accumulated reward -184.0
# accumulated reward -185.0
# accumulated reward -186.0
# accumulated reward -187.0
# accumulated reward -188.0
# accumulated reward -189.0
# accumulated reward -190.0
# accumulated reward -191.0
# accumulated reward -192.0
# accumulated reward -193.0
# accumulated reward -194.0
# accumulated reward -195.0
# accumulated reward -196.0
# accumulated reward -197.0
# accumulated reward -198.0
# accumulated reward -199.0
# accumulated reward -200.0
# accumulated reward -201.0
# accumulated reward -202.0
# accumulated reward -203.0
# accumulated reward -204.0
# accumulated reward -205.0
# accumulated reward -206.0
# accumulated reward -207.0
# accumulated reward -208.0
# accumulated reward -209.0
# accumulated reward -210.0
# accumulated reward -211.0
# accumulated reward -212.0
# accumulated reward -213.0
# accumulated reward -214.0
# accumulated reward -215.0
# accumulated reward -216.0
# accumulated reward -217.0
# accumulated reward -218.0
# accumulated reward -219.0
# accumulated reward -220.0
# accumulated reward -221.0
# accumulated reward -222.0
# accumulated reward -223.0
# accumulated reward -224.0
# accumulated reward -225.0
# accumulated reward -226.0
# accumulated reward -227.0
# accumulated reward -228.0
# accumulated reward -229.0
# accumulated reward -230.0
# accumulated reward -231.0
# accumulated reward -232.0
# accumulated reward -233.0
# accumulated reward -234.0
# accumulated reward -235.0
# accumulated reward -236.0
# accumulated reward -237.0
# accumulated reward -238.0
# accumulated reward -239.0
# accumulated reward -240.0
# accumulated reward -241.0
# accumulated reward -242.0
# accumulated reward -243.0
# accumulated reward -244.0
# accumulated reward -245.0
# accumulated reward -246.0
# accumulated reward -247.0
# accumulated reward -248.0
# accumulated reward -249.0
# accumulated reward -250.0
# accumulated reward -251.0
# accumulated reward -252.0
# accumulated reward -253.0
# accumulated reward -254.0
# accumulated reward -255.0
# accumulated reward -256.0
# accumulated reward -257.0
# accumulated reward -258.0
# accumulated reward -259.0
# accumulated reward -260.0
# accumulated reward -261.0
# accumulated reward -262.0
# accumulated reward -263.0
# accumulated reward -264.0
# accumulated reward -265.0
# accumulated reward -266.0
# accumulated reward -267.0
# accumulated reward -268.0
# accumulated reward -269.0
# accumulated reward -270.0
# accumulated reward -271.0
# accumulated reward -272.0
# accumulated reward -273.0
# accumulated reward -274.0
# accumulated reward -275.0
# accumulated reward -276.0
# accumulated reward -277.0
# accumulated reward -278.0
# accumulated reward -279.0
# accumulated reward -280.0
# accumulated reward -281.0
# accumulated reward -282.0
# accumulated reward -283.0
# accumulated reward -284.0
# accumulated reward -285.0
# accumulated reward -286.0
# accumulated reward -287.0
# accumulated reward -288.0
# accumulated reward -289.0
# accumulated reward -290.0
# accumulated reward -291.0
# accumulated reward -292.0
# accumulated reward -293.0
# accumulated reward -294.0
# accumulated reward -295.0
# accumulated reward -296.0
# accumulated reward -297.0
# accumulated reward -298.0
# accumulated reward -299.0
# accumulated reward -300.0
# accumulated reward -301.0
# accumulated reward -302.0
# accumulated reward -303.0
# accumulated reward -304.0
# accumulated reward -305.0
# accumulated reward -306.0
# accumulated reward -307.0
# accumulated reward -308.0
# accumulated reward -309.0
# accumulated reward -310.0
# accumulated reward -311.0
# accumulated reward -312.0
# accumulated reward -313.0
# accumulated reward -314.0
# accumulated reward -315.0
# accumulated reward -316.0
# accumulated reward -317.0
# accumulated reward -318.0
# accumulated reward -319.0
# accumulated reward -320.0
# accumulated reward -321.0
# accumulated reward -322.0
# accumulated reward -323.0
# accumulated reward -324.0
# accumulated reward -325.0
# accumulated reward -326.0
# accumulated reward -327.0
# accumulated reward -328.0
# accumulated reward -329.0
# accumulated reward -330.0
# accumulated reward -331.0
# accumulated reward -332.0
# accumulated reward -333.0
# accumulated reward -334.0
# accumulated reward -335.0
# accumulated reward -336.0
# accumulated reward -337.0
# accumulated reward -338.0
# accumulated reward -339.0
# accumulated reward -340.0
# accumulated reward -341.0
# accumulated reward -342.0
# accumulated reward -343.0
# accumulated reward -344.0
# accumulated reward -345.0
# accumulated reward -346.0
# accumulated reward -347.0
# accumulated reward -348.0
# accumulated reward -349.0
# accumulated reward -350.0
# accumulated reward -351.0
# accumulated reward -352.0
# accumulated reward -353.0
# accumulated reward -354.0
# accumulated reward -355.0
# accumulated reward -356.0
# accumulated reward -357.0
# accumulated reward -358.0
# accumulated reward -359.0
# accumulated reward -360.0
# accumulated reward -361.0
# accumulated reward -362.0
# accumulated reward -363.0
# accumulated reward -364.0
# accumulated reward -365.0
# accumulated reward -366.0
# accumulated reward -367.0
# accumulated reward -368.0
# accumulated reward -369.0
# accumulated reward -370.0
# accumulated reward -371.0
# accumulated reward -372.0
# accumulated reward -373.0
# accumulated reward -374.0
# accumulated reward -375.0
# accumulated reward -376.0
# accumulated reward -377.0
# accumulated reward -378.0
# accumulated reward -379.0
# accumulated reward -380.0
# accumulated reward -381.0
# accumulated reward -382.0
# accumulated reward -383.0
# accumulated reward -384.0
# accumulated reward -385.0
# accumulated reward -386.0
# accumulated reward -387.0
# accumulated reward -388.0
# accumulated reward -389.0
# accumulated reward -390.0
# accumulated reward -391.0
# accumulated reward -392.0
# accumulated reward -393.0
# accumulated reward -394.0
# accumulated reward -395.0
# accumulated reward -396.0
# accumulated reward -397.0
# accumulated reward -398.0
# accumulated reward -399.0
# accumulated reward -400.0
# accumulated reward -401.0
# accumulated reward -402.0
# accumulated reward -403.0
# accumulated reward -404.0
# accumulated reward -405.0
# accumulated reward -406.0
# accumulated reward -407.0
# accumulated reward -408.0
# accumulated reward -409.0
# accumulated reward -410.0
# accumulated reward -411.0
# accumulated reward -412.0
# accumulated reward -413.0
# accumulated reward -414.0
# accumulated reward -415.0
# accumulated reward -416.0
# accumulated reward -417.0
# accumulated reward -418.0
# accumulated reward -419.0
# accumulated reward -420.0
# accumulated reward -421.0
# accumulated reward -422.0
# accumulated reward -423.0
# accumulated reward -424.0
# accumulated reward -425.0
# accumulated reward -426.0
# accumulated reward -427.0
# accumulated reward -428.0
# accumulated reward -429.0
# accumulated reward -430.0
# accumulated reward -431.0
# accumulated reward -432.0
# accumulated reward -433.0
# accumulated reward -434.0
# accumulated reward -435.0
# accumulated reward -436.0
# accumulated reward -437.0
# accumulated reward -438.0
# accumulated reward -439.0
# accumulated reward -440.0
# accumulated reward -441.0
# accumulated reward -442.0
# accumulated reward -443.0
# accumulated reward -444.0
# accumulated reward -445.0
# accumulated reward -446.0
# accumulated reward -447.0
# accumulated reward -448.0
# accumulated reward -449.0
# accumulated reward -450.0
# accumulated reward -451.0
# accumulated reward -452.0
# accumulated reward -453.0
# accumulated reward -454.0
# accumulated reward -455.0
# accumulated reward -456.0
# accumulated reward -457.0
# accumulated reward -458.0
# accumulated reward -459.0
# accumulated reward -460.0
# accumulated reward -461.0
# accumulated reward -462.0
# accumulated reward -463.0
# accumulated reward -464.0
# accumulated reward -465.0
# accumulated reward -466.0
# accumulated reward -467.0
# accumulated reward -468.0
# accumulated reward -469.0
# accumulated reward -470.0
# accumulated reward -471.0
# accumulated reward -472.0
# accumulated reward -473.0
# accumulated reward -474.0
# accumulated reward -475.0
# accumulated reward -476.0
# accumulated reward -477.0
# accumulated reward -478.0
# accumulated reward -479.0
# accumulated reward -480.0
# accumulated reward -481.0
# accumulated reward -482.0
# accumulated reward -483.0
# accumulated reward -484.0
# accumulated reward -485.0
# accumulated reward -486.0
# accumulated reward -487.0
# accumulated reward -488.0
# accumulated reward -489.0
# accumulated reward -490.0
# accumulated reward -491.0
# accumulated reward -492.0
# accumulated reward -493.0
# accumulated reward -494.0
# accumulated reward -495.0
# accumulated reward -496.0
# accumulated reward -497.0
# accumulated reward -498.0
# accumulated reward -499.0
# accumulated reward -500.0
# accumulated reward -501.0
# accumulated reward -502.0
# accumulated reward -503.0
# accumulated reward -504.0
# accumulated reward -505.0
# accumulated reward -506.0
# accumulated reward -507.0
# accumulated reward -508.0
# accumulated reward -509.0
# accumulated reward -510.0
# accumulated reward -511.0
# accumulated reward -512.0
# accumulated reward -513.0
# accumulated reward -514.0
# accumulated reward -515.0
# accumulated reward -516.0
# accumulated reward -517.0
# accumulated reward -518.0
# accumulated reward -519.0
# accumulated reward -520.0
# accumulated reward -521.0
# accumulated reward -522.0
# accumulated reward -523.0
# accumulated reward -524.0
# accumulated reward -525.0
# accumulated reward -526.0
# accumulated reward -527.0
# accumulated reward -528.0
# accumulated reward -529.0
# accumulated reward -530.0
# accumulated reward -531.0
# accumulated reward -532.0
# accumulated reward -533.0
# accumulated reward -534.0
# accumulated reward -535.0
# accumulated reward -536.0
# accumulated reward -537.0
# accumulated reward -538.0
# accumulated reward -539.0
# accumulated reward -540.0
# accumulated reward -541.0
# accumulated reward -542.0
# accumulated reward -543.0
# accumulated reward -544.0
# accumulated reward -545.0
# accumulated reward -546.0
# accumulated reward -547.0
# accumulated reward -548.0
# accumulated reward -549.0
# accumulated reward -550.0
# accumulated reward -551.0
# accumulated reward -552.0
# accumulated reward -553.0
# accumulated reward -554.0
# accumulated reward -555.0
# accumulated reward -556.0
# accumulated reward -557.0
# accumulated reward -558.0
# accumulated reward -559.0
# accumulated reward -560.0
# accumulated reward -561.0
# accumulated reward -562.0
# accumulated reward -563.0
# accumulated reward -564.0
# accumulated reward -565.0
# accumulated reward -566.0
# accumulated reward -567.0
# accumulated reward -568.0
# accumulated reward -569.0
# accumulated reward -570.0
# accumulated reward -571.0
# accumulated reward -572.0
# accumulated reward -573.0
# accumulated reward -574.0
# accumulated reward -575.0
# accumulated reward -576.0
# accumulated reward -577.0
# accumulated reward -578.0
# accumulated reward -579.0
# accumulated reward -580.0
# accumulated reward -581.0
# accumulated reward -582.0
# accumulated reward -583.0
# accumulated reward -584.0
# accumulated reward -585.0
# accumulated reward -586.0
# accumulated reward -587.0
# accumulated reward -588.0
# accumulated reward -589.0
# accumulated reward -590.0
# accumulated reward -591.0
# accumulated reward -592.0
# accumulated reward -593.0
# accumulated reward -594.0
# accumulated reward -595.0
# accumulated reward -596.0
# accumulated reward -597.0
# accumulated reward -598.0
# accumulated reward -599.0
# accumulated reward -600.0
# accumulated reward -601.0
# accumulated reward -602.0
# accumulated reward -603.0
# accumulated reward -604.0
# accumulated reward -605.0
# accumulated reward -606.0
# accumulated reward -607.0
# accumulated reward -608.0
# accumulated reward -609.0
# accumulated reward -610.0
# accumulated reward -611.0
# accumulated reward -612.0
# accumulated reward -613.0
# accumulated reward -614.0
# accumulated reward -615.0
# accumulated reward -616.0
# accumulated reward -617.0
# accumulated reward -618.0
# accumulated reward -619.0
# accumulated reward -620.0
# accumulated reward -621.0
# accumulated reward -622.0
# accumulated reward -623.0
# accumulated reward -624.0
# accumulated reward -625.0
# accumulated reward -626.0
# accumulated reward -627.0
# accumulated reward -628.0
# accumulated reward -629.0
# accumulated reward -630.0
# accumulated reward -631.0
# accumulated reward -632.0
# accumulated reward -633.0
# accumulated reward -634.0
# accumulated reward -635.0
# accumulated reward -636.0
# accumulated reward -637.0
# accumulated reward -638.0
# accumulated reward -639.0
# accumulated reward -640.0
# accumulated reward -641.0
# accumulated reward -642.0
# accumulated reward -643.0
# accumulated reward -644.0
# accumulated reward -645.0
# accumulated reward -646.0
# accumulated reward -647.0
# accumulated reward -648.0
# accumulated reward -649.0
# accumulated reward -650.0
# accumulated reward -651.0
# accumulated reward -652.0
# accumulated reward -653.0
# accumulated reward -654.0
# accumulated reward -655.0
# accumulated reward -656.0
# accumulated reward -657.0
# accumulated reward -658.0
# accumulated reward -659.0
# accumulated reward -660.0
# accumulated reward -661.0
# accumulated reward -662.0
# accumulated reward -663.0
# accumulated reward -664.0
# accumulated reward -665.0
# accumulated reward -666.0
# accumulated reward -667.0
# accumulated reward -668.0
# accumulated reward -669.0
# accumulated reward -670.0
# accumulated reward -671.0
# accumulated reward -672.0
# accumulated reward -673.0
# accumulated reward -674.0
# accumulated reward -675.0
# accumulated reward -676.0
# accumulated reward -677.0
# accumulated reward -678.0
# accumulated reward -679.0
# accumulated reward -680.0
# accumulated reward -681.0
# accumulated reward -682.0
# accumulated reward -683.0
# accumulated reward -684.0
# accumulated reward -685.0
# accumulated reward -686.0
# accumulated reward -687.0
# accumulated reward -688.0
# accumulated reward -689.0
# accumulated reward -690.0
# accumulated reward -691.0
# accumulated reward -692.0
# accumulated reward -693.0
# accumulated reward -694.0
# accumulated reward -695.0
# accumulated reward -696.0
# accumulated reward -697.0
# accumulated reward -698.0
# accumulated reward -699.0
# accumulated reward -700.0
# accumulated reward -701.0
# accumulated reward -702.0
# accumulated reward -703.0
# accumulated reward -704.0
# accumulated reward -705.0
# accumulated reward -706.0
# accumulated reward -707.0
# accumulated reward -708.0
# accumulated reward -709.0
# accumulated reward -710.0
# accumulated reward -711.0
# accumulated reward -712.0
# accumulated reward -713.0
# accumulated reward -714.0
# accumulated reward -715.0
# accumulated reward -716.0
# accumulated reward -717.0
# accumulated reward -718.0
# accumulated reward -719.0
# accumulated reward -720.0
# accumulated reward -721.0
# accumulated reward -722.0
# accumulated reward -723.0
# accumulated reward -724.0
# accumulated reward -725.0
# accumulated reward -726.0
# accumulated reward -727.0
# accumulated reward -728.0
# accumulated reward -729.0
# accumulated reward -730.0
# accumulated reward -731.0
# accumulated reward -732.0
# accumulated reward -733.0
# accumulated reward -734.0
# accumulated reward -735.0
# accumulated reward -736.0
# accumulated reward -737.0
# accumulated reward -738.0
# accumulated reward -739.0
# accumulated reward -740.0
# accumulated reward -741.0
# accumulated reward -742.0
# accumulated reward -743.0
# accumulated reward -744.0
# accumulated reward -745.0
# accumulated reward -746.0
# accumulated reward -747.0
# accumulated reward -748.0
# accumulated reward -749.0
# accumulated reward -750.0
# accumulated reward -751.0
# accumulated reward -752.0
# accumulated reward -753.0
# accumulated reward -754.0
# accumulated reward -755.0
# accumulated reward -756.0
# accumulated reward -757.0
# accumulated reward -758.0
# accumulated reward -759.0
# accumulated reward -760.0
# accumulated reward -761.0
# accumulated reward -762.0
# accumulated reward -763.0
# accumulated reward -764.0
# accumulated reward -765.0
# accumulated reward -766.0
# accumulated reward -767.0
# accumulated reward -768.0
# accumulated reward -769.0
# accumulated reward -770.0
# accumulated reward -771.0
# accumulated reward -772.0
# accumulated reward -773.0
# accumulated reward -774.0
# accumulated reward -775.0
# accumulated reward -776.0
# accumulated reward -777.0
# accumulated reward -778.0
# accumulated reward -779.0
# accumulated reward -780.0
# accumulated reward -781.0
# accumulated reward -782.0
# accumulated reward -783.0
# accumulated reward -784.0
# accumulated reward -785.0
# accumulated reward -786.0
# accumulated reward -787.0
# accumulated reward -788.0
# accumulated reward -789.0
# accumulated reward -790.0
# accumulated reward -791.0
# accumulated reward -792.0
# accumulated reward -793.0
# accumulated reward -794.0
# accumulated reward -795.0
# accumulated reward -796.0
# accumulated reward -797.0
# accumulated reward -798.0
# accumulated reward -799.0
# accumulated reward -800.0
# accumulated reward -801.0
# accumulated reward -802.0
# accumulated reward -803.0
# accumulated reward -804.0
# accumulated reward -805.0
# accumulated reward -806.0
# accumulated reward -807.0
# accumulated reward -808.0
# accumulated reward -809.0
# accumulated reward -810.0
# accumulated reward -811.0
# accumulated reward -812.0
# accumulated reward -813.0
# accumulated reward -814.0
# accumulated reward -815.0
# accumulated reward -816.0
# accumulated reward -817.0
# accumulated reward -818.0
# accumulated reward -819.0
# accumulated reward -820.0
# accumulated reward -821.0
# accumulated reward -822.0
# accumulated reward -823.0
# accumulated reward -824.0
# accumulated reward -825.0
# accumulated reward -826.0
# accumulated reward -827.0
# accumulated reward -828.0
# accumulated reward -829.0
# accumulated reward -830.0
# accumulated reward -831.0
# accumulated reward -832.0
# accumulated reward -833.0
# accumulated reward -834.0
# accumulated reward -835.0
# accumulated reward -836.0
# accumulated reward -837.0
# accumulated reward -838.0
# accumulated reward -839.0
# accumulated reward -840.0
# accumulated reward -841.0
# accumulated reward -842.0
# accumulated reward -843.0
# accumulated reward -844.0
# accumulated reward -845.0
# accumulated reward -846.0
# accumulated reward -847.0
# accumulated reward -848.0
# accumulated reward -849.0
# accumulated reward -850.0
# accumulated reward -851.0
# accumulated reward -852.0
# accumulated reward -853.0
# accumulated reward -854.0
# accumulated reward -855.0
# accumulated reward -856.0
# accumulated reward -857.0
# accumulated reward -858.0
# accumulated reward -859.0
# accumulated reward -860.0
# accumulated reward -861.0
# accumulated reward -862.0
# accumulated reward -863.0
# accumulated reward -864.0
# accumulated reward -865.0
# accumulated reward -866.0
# accumulated reward -867.0
# accumulated reward -868.0
# accumulated reward -869.0
# accumulated reward -870.0
# accumulated reward -871.0
# accumulated reward -872.0
# accumulated reward -873.0
# accumulated reward -874.0
# accumulated reward -875.0
# accumulated reward -876.0
# accumulated reward -877.0
# accumulated reward -878.0
# accumulated reward -879.0
# accumulated reward -880.0
# accumulated reward -881.0
# accumulated reward -882.0
# accumulated reward -883.0
# accumulated reward -884.0
# accumulated reward -885.0
# accumulated reward -886.0
# accumulated reward -887.0
# accumulated reward -888.0
# accumulated reward -889.0
# accumulated reward -890.0
# accumulated reward -891.0
# accumulated reward -892.0
# accumulated reward -893.0
# accumulated reward -894.0
# accumulated reward -895.0
# accumulated reward -896.0
# accumulated reward -897.0
# accumulated reward -898.0
# accumulated reward -899.0
# accumulated reward -900.0
# accumulated reward -901.0
# accumulated reward -902.0
# accumulated reward -903.0
# accumulated reward -904.0
# accumulated reward -905.0
# accumulated reward -906.0
# accumulated reward -907.0
# accumulated reward -908.0
# accumulated reward -909.0
# accumulated reward -910.0
# accumulated reward -911.0
# accumulated reward -912.0
# accumulated reward -913.0
# accumulated reward -914.0
# accumulated reward -915.0
# accumulated reward -916.0
# accumulated reward -917.0
# accumulated reward -918.0
# accumulated reward -919.0
# accumulated reward -920.0
# accumulated reward -921.0
# accumulated reward -922.0
# accumulated reward -923.0
# accumulated reward -924.0
# accumulated reward -925.0
# accumulated reward -926.0
# accumulated reward -927.0
# accumulated reward -928.0
# accumulated reward -929.0
# accumulated reward -930.0
# accumulated reward -931.0
# accumulated reward -932.0
# accumulated reward -933.0
# accumulated reward -934.0
# accumulated reward -935.0
# accumulated reward -936.0
# accumulated reward -937.0
# accumulated reward -938.0
# accumulated reward -939.0
# accumulated reward -940.0
# accumulated reward -941.0
# accumulated reward -942.0
# accumulated reward -943.0
# accumulated reward -944.0
# accumulated reward -945.0
# accumulated reward -946.0
# accumulated reward -947.0
# accumulated reward -948.0
# accumulated reward -949.0
# accumulated reward -950.0
# accumulated reward -951.0
# accumulated reward -952.0
# accumulated reward -953.0
# accumulated reward -954.0
# accumulated reward -955.0
# accumulated reward -956.0
# accumulated reward -957.0
# accumulated reward -958.0
# accumulated reward -959.0
# accumulated reward -960.0
# accumulated reward -961.0
# accumulated reward -962.0
# accumulated reward -963.0
# accumulated reward -964.0
# accumulated reward -965.0
# accumulated reward -966.0
# accumulated reward -967.0
# accumulated reward -968.0
# accumulated reward -969.0
# accumulated reward -970.0
# accumulated reward -971.0
# accumulated reward -972.0
# accumulated reward -973.0
# accumulated reward -974.0
# accumulated reward -975.0
# accumulated reward -976.0
# accumulated reward -977.0
# accumulated reward -978.0
# accumulated reward -979.0
# accumulated reward -980.0
# accumulated reward -981.0
# accumulated reward -982.0
# accumulated reward -983.0
# accumulated reward -984.0
# accumulated reward -985.0
# accumulated reward -986.0
# accumulated reward -987.0
# accumulated reward -988.0
# accumulated reward -989.0
# accumulated reward -990.0
# accumulated reward -991.0
# accumulated reward -992.0
# accumulated reward -993.0
# accumulated reward -994.0
# accumulated reward -995.0
# accumulated reward -996.0
# accumulated reward -997.0
# accumulated reward -998.0
# accumulated reward -999.0
# accumulated reward -1000.0
# accumulated reward -1001.0
# accumulated reward -1002.0
# accumulated reward -1003.0
# accumulated reward -1004.0
# accumulated reward -1005.0
# accumulated reward -1006.0
# accumulated reward -1007.0
# accumulated reward -1008.0
# accumulated reward -1009.0
# accumulated reward -1010.0
# accumulated reward -1011.0
# accumulated reward -1012.0
# accumulated reward -1013.0
# accumulated reward -1014.0
# accumulated reward -1015.0
# accumulated reward -1016.0
# accumulated reward -1017.0
# accumulated reward -1018.0
# accumulated reward -1019.0
# accumulated reward -1020.0
# accumulated reward -1021.0
# accumulated reward -1022.0
# accumulated reward -1023.0
# accumulated reward -1024.0
# accumulated reward -1025.0
# accumulated reward -1026.0
# accumulated reward -1027.0
# accumulated reward -1028.0
# accumulated reward -1029.0
# accumulated reward -1030.0
# accumulated reward -1031.0
# accumulated reward -1032.0
# accumulated reward -1033.0
# accumulated reward -1034.0
# accumulated reward -1035.0
# accumulated reward -1036.0
# accumulated reward -1037.0
# accumulated reward -1038.0
# accumulated reward -1039.0
# accumulated reward -1040.0
# accumulated reward -1041.0
# accumulated reward -1042.0
# accumulated reward -1043.0
# accumulated reward -1044.0
# accumulated reward -1045.0
# accumulated reward -1046.0
# accumulated reward -1047.0
# accumulated reward -1048.0
# accumulated reward -1049.0
# accumulated reward -1050.0
# accumulated reward -1051.0
# accumulated reward -1052.0
# accumulated reward -1053.0
# accumulated reward -1054.0
# accumulated reward -1055.0
# accumulated reward -1056.0
# accumulated reward -1057.0
# accumulated reward -1058.0
# accumulated reward -1059.0
# accumulated reward -1060.0
# accumulated reward -1061.0
# accumulated reward -1062.0
# accumulated reward -1063.0
# accumulated reward -1064.0
# accumulated reward -1065.0
# accumulated reward -1066.0
# accumulated reward -1067.0
# accumulated reward -1068.0
# accumulated reward -1069.0
# accumulated reward -1070.0
# accumulated reward -1071.0
# accumulated reward -1072.0
# accumulated reward -1073.0
# accumulated reward -1074.0
# accumulated reward -1075.0
# accumulated reward -1076.0
# accumulated reward -1077.0
# accumulated reward -1078.0
# accumulated reward -1079.0
# accumulated reward -1080.0
# accumulated reward -1081.0
# accumulated reward -1082.0
# accumulated reward -1083.0
# accumulated reward -1084.0
# accumulated reward -1085.0
# accumulated reward -1086.0
# accumulated reward -1087.0
# accumulated reward -1088.0
# accumulated reward -1089.0
# accumulated reward -1090.0
# accumulated reward -1091.0
# accumulated reward -1092.0
# accumulated reward -1093.0
# accumulated reward -1094.0
# accumulated reward -1095.0
# accumulated reward -1096.0
# accumulated reward -1097.0
# accumulated reward -1098.0
# accumulated reward -1099.0
# accumulated reward -1100.0
# accumulated reward -1101.0
# accumulated reward -1102.0
# accumulated reward -1103.0
# accumulated reward -1104.0
# accumulated reward -1105.0
# accumulated reward -1106.0
# accumulated reward -1107.0
# accumulated reward -1108.0
# accumulated reward -1109.0
# accumulated reward -1110.0
# accumulated reward -1111.0
# accumulated reward -1112.0
# accumulated reward -1113.0
# accumulated reward -1114.0
# accumulated reward -1115.0
# accumulated reward -1116.0
# accumulated reward -1117.0
# accumulated reward -1118.0
# accumulated reward -1119.0
# accumulated reward -1120.0
# accumulated reward -1121.0
# accumulated reward -1122.0
# accumulated reward -1123.0
# accumulated reward -1124.0
# accumulated reward -1125.0
# accumulated reward -1126.0
# accumulated reward -1127.0
# accumulated reward -1128.0
# accumulated reward -1129.0
# accumulated reward -1130.0
# accumulated reward -1131.0
# accumulated reward -1132.0
# accumulated reward -1133.0
# accumulated reward -1134.0
# accumulated reward -1135.0
# accumulated reward -1136.0
# accumulated reward -1137.0
# accumulated reward -1138.0
# accumulated reward -1139.0
# accumulated reward -1140.0
# accumulated reward -1141.0
# accumulated reward -1142.0
# accumulated reward -1143.0
# accumulated reward -1144.0
# accumulated reward -1145.0
# accumulated reward -1146.0
# accumulated reward -1147.0
# accumulated reward -1148.0
# accumulated reward -1149.0
# accumulated reward -1150.0
# accumulated reward -1151.0
# accumulated reward -1152.0
# accumulated reward -1153.0
# accumulated reward -1154.0
# accumulated reward -1155.0
# accumulated reward -1156.0
# accumulated reward -1157.0
# accumulated reward -1158.0
# accumulated reward -1159.0
# accumulated reward -1160.0
# accumulated reward -1161.0
# accumulated reward -1162.0
# accumulated reward -1163.0
# accumulated reward -1164.0
# accumulated reward -1165.0
# accumulated reward -1166.0
# accumulated reward -1167.0
# accumulated reward -1168.0
# accumulated reward -1169.0
# accumulated reward -1170.0
# accumulated reward -1171.0
# accumulated reward -1172.0
# accumulated reward -1173.0
# accumulated reward -1174.0
# accumulated reward -1175.0
# accumulated reward -1176.0
# accumulated reward -1177.0
# accumulated reward -1178.0
# accumulated reward -1179.0
# accumulated reward -1180.0
# accumulated reward -1181.0
# accumulated reward -1182.0
# accumulated reward -1183.0
# accumulated reward -1184.0
# accumulated reward -1185.0
# accumulated reward -1186.0
# accumulated reward -1187.0
# accumulated reward -1188.0
# accumulated reward -1189.0
# accumulated reward -1190.0
# accumulated reward -1191.0
# accumulated reward -1192.0
# accumulated reward -1193.0
# accumulated reward -1194.0
# accumulated reward -1195.0
# accumulated reward -1196.0
# accumulated reward -1197.0
# accumulated reward -1198.0
# accumulated reward -1199.0
# accumulated reward -1200.0
# accumulated reward -1201.0
# accumulated reward -1202.0
# accumulated reward -1203.0
# accumulated reward -1204.0
# accumulated reward -1205.0
# accumulated reward -1206.0
# accumulated reward -1207.0
# accumulated reward -1208.0
# accumulated reward -1209.0
# accumulated reward -1210.0
# accumulated reward -1211.0
# accumulated reward -1212.0
# accumulated reward -1213.0
# accumulated reward -1214.0
# accumulated reward -1215.0
# accumulated reward -1216.0
# accumulated reward -1217.0
# accumulated reward -1218.0
# accumulated reward -1219.0
# accumulated reward -1220.0
# accumulated reward -1221.0
# accumulated reward -1222.0
# accumulated reward -1223.0
# accumulated reward -1224.0
# accumulated reward -1225.0
# accumulated reward -1226.0
# accumulated reward -1227.0
# accumulated reward -1228.0
# accumulated reward -1229.0
# accumulated reward -1230.0
# accumulated reward -1231.0
# accumulated reward -1232.0
# accumulated reward -1233.0
# accumulated reward -1234.0
# accumulated reward -1235.0
# accumulated reward -1236.0
# accumulated reward -1237.0
# accumulated reward -1238.0
# accumulated reward -1239.0
# accumulated reward -1240.0
# accumulated reward -1241.0
# accumulated reward -1242.0
# accumulated reward -1243.0
# accumulated reward -1244.0
# accumulated reward -1245.0
# accumulated reward -1246.0
# accumulated reward -1247.0
# accumulated reward -1248.0
# accumulated reward -1249.0
# accumulated reward -1250.0
# accumulated reward -1251.0
# accumulated reward -1252.0
# accumulated reward -1253.0
# accumulated reward -1254.0
# accumulated reward -1255.0
# accumulated reward -1256.0
# accumulated reward -1257.0
# accumulated reward -1258.0
# accumulated reward -1259.0
# accumulated reward -1260.0
# accumulated reward -1261.0
# accumulated reward -1262.0
# accumulated reward -1263.0
# accumulated reward -1264.0
# accumulated reward -1265.0
# accumulated reward -1266.0
# accumulated reward -1267.0
# accumulated reward -1268.0
# accumulated reward -1269.0
# accumulated reward -1270.0
# accumulated reward -1271.0
# accumulated reward -1272.0
# accumulated reward -1273.0
# accumulated reward -1274.0
# accumulated reward -1275.0
# accumulated reward -1276.0
# accumulated reward -1277.0
# accumulated reward -1278.0
# accumulated reward -1279.0
# accumulated reward -1280.0
# accumulated reward -1281.0
# accumulated reward -1282.0
# accumulated reward -1283.0
# accumulated reward -1284.0
# accumulated reward -1285.0
# accumulated reward -1286.0
# accumulated reward -1287.0
# accumulated reward -1288.0
# accumulated reward -1289.0
# accumulated reward -1290.0
# accumulated reward -1291.0
# accumulated reward -1292.0
# accumulated reward -1293.0
# accumulated reward -1294.0
# accumulated reward -1295.0
# accumulated reward -1296.0
# accumulated reward -1297.0
# accumulated reward -1298.0
# accumulated reward -1299.0
# accumulated reward -1300.0
# accumulated reward -1301.0
# accumulated reward -1302.0
# accumulated reward -1303.0
# accumulated reward -1304.0
# accumulated reward -1305.0
# accumulated reward -1306.0
# accumulated reward -1307.0
# accumulated reward -1308.0
# accumulated reward -1309.0
# accumulated reward -1310.0
# accumulated reward -1311.0
# accumulated reward -1312.0
# accumulated reward -1313.0
# accumulated reward -1314.0
# accumulated reward -1315.0
# accumulated reward -1316.0
# accumulated reward -1317.0
# accumulated reward -1318.0
# accumulated reward -1319.0
# accumulated reward -1320.0
# accumulated reward -1321.0
# accumulated reward -1322.0
# accumulated reward -1323.0
# accumulated reward -1324.0
# accumulated reward -1325.0
# accumulated reward -1326.0
# accumulated reward -1327.0
# accumulated reward -1328.0
# accumulated reward -1329.0
# accumulated reward -1330.0
# accumulated reward -1331.0
# accumulated reward -1332.0
# accumulated reward -1333.0
# accumulated reward -1334.0
# accumulated reward -1335.0
# accumulated reward -1336.0
# accumulated reward -1337.0
# accumulated reward -1338.0
# accumulated reward -1339.0
# accumulated reward -1340.0
# accumulated reward -1341.0
# accumulated reward -1342.0
# accumulated reward -1343.0
# accumulated reward -1344.0
# accumulated reward -1345.0
# accumulated reward -1346.0
# accumulated reward -1347.0
# accumulated reward -1348.0
# accumulated reward -1349.0
# accumulated reward -1350.0
# accumulated reward -1351.0
# accumulated reward -1352.0
# accumulated reward -1353.0
# accumulated reward -1354.0
# accumulated reward -1355.0
# accumulated reward -1356.0
# accumulated reward -1357.0
# accumulated reward -1358.0
# accumulated reward -1359.0
# accumulated reward -1360.0
# accumulated reward -1361.0
# accumulated reward -1362.0
# accumulated reward -1363.0
# accumulated reward -1364.0
# accumulated reward -1365.0
# accumulated reward -1366.0
# accumulated reward -1367.0
# accumulated reward -1368.0
# accumulated reward -1369.0
# accumulated reward -1370.0
# accumulated reward -1371.0
# accumulated reward -1372.0
# accumulated reward -1373.0
# accumulated reward -1374.0
# accumulated reward -1375.0
# accumulated reward -1376.0
# accumulated reward -1377.0
# accumulated reward -1378.0
# accumulated reward -1379.0
# accumulated reward -1380.0
# accumulated reward -1381.0
# accumulated reward -1382.0
# accumulated reward -1383.0
# accumulated reward -1384.0
# accumulated reward -1385.0
# accumulated reward -1386.0
# accumulated reward -1387.0
# accumulated reward -1388.0
# accumulated reward -1389.0
# accumulated reward -1390.0
# accumulated reward -1391.0
# accumulated reward -1392.0
# accumulated reward -1393.0
# accumulated reward -1394.0
# accumulated reward -1395.0
# accumulated reward -1396.0
# accumulated reward -1397.0
# accumulated reward -1398.0
# accumulated reward -1399.0
# accumulated reward -1400.0
# accumulated reward -1401.0
# accumulated reward -1402.0
# accumulated reward -1403.0
# accumulated reward -1404.0
# accumulated reward -1405.0
# accumulated reward -1406.0
# accumulated reward -1407.0
# accumulated reward -1408.0
# accumulated reward -1409.0
# accumulated reward -1410.0
# accumulated reward -1411.0
# accumulated reward -1412.0
# accumulated reward -1413.0
# accumulated reward -1414.0
# accumulated reward -1415.0
# accumulated reward -1416.0
# accumulated reward -1417.0
# accumulated reward -1418.0
# accumulated reward -1419.0
# accumulated reward -1420.0
# accumulated reward -1421.0
# accumulated reward -1422.0
# accumulated reward -1423.0
# accumulated reward -1424.0
# accumulated reward -1425.0
# accumulated reward -1426.0
# accumulated reward -1427.0
# accumulated reward -1428.0
# accumulated reward -1429.0
# accumulated reward -1430.0
# accumulated reward -1431.0
# accumulated reward -1432.0
# accumulated reward -1433.0
# accumulated reward -1434.0
# accumulated reward -1435.0
# accumulated reward -1436.0
# accumulated reward -1437.0
# accumulated reward -1438.0
# accumulated reward -1439.0
# accumulated reward -1440.0
# accumulated reward -1441.0
# accumulated reward -1442.0
# accumulated reward -1443.0
# accumulated reward -1444.0
# accumulated reward -1445.0
# accumulated reward -1446.0
# accumulated reward -1447.0
# accumulated reward -1448.0
# accumulated reward -1449.0
# accumulated reward -1450.0
# accumulated reward -1451.0
# accumulated reward -1452.0
# accumulated reward -1453.0
# accumulated reward -1454.0
# accumulated reward -1455.0
# accumulated reward -1456.0
# accumulated reward -1457.0
# accumulated reward -1458.0
# accumulated reward -1459.0
# accumulated reward -1460.0
# accumulated reward -1461.0
# accumulated reward -1462.0
# accumulated reward -1463.0
# accumulated reward -1464.0
# accumulated reward -1465.0
# accumulated reward -1466.0
# accumulated reward -1467.0
# accumulated reward -1468.0
# accumulated reward -1469.0
# accumulated reward -1470.0
# accumulated reward -1471.0
# accumulated reward -1472.0
# accumulated reward -1473.0
# accumulated reward -1474.0
# accumulated reward -1475.0
# accumulated reward -1476.0
# accumulated reward -1477.0
# accumulated reward -1478.0
# accumulated reward -1479.0
# accumulated reward -1480.0
# accumulated reward -1481.0
# accumulated reward -1482.0
# accumulated reward -1483.0
# accumulated reward -1484.0
# accumulated reward -1485.0
# accumulated reward -1486.0
# accumulated reward -1487.0
# accumulated reward -1488.0
# accumulated reward -1489.0
# accumulated reward -1490.0
# accumulated reward -1491.0
# accumulated reward -1492.0
# accumulated reward -1493.0
# accumulated reward -1494.0
# accumulated reward -1495.0
# accumulated reward -1496.0
# accumulated reward -1497.0
# accumulated reward -1498.0
# accumulated reward -1499.0
# accumulated reward -1500.0
# accumulated reward -1501.0
# accumulated reward -1502.0
# accumulated reward -1503.0
# accumulated reward -1504.0
# accumulated reward -1505.0
# accumulated reward -1506.0
# accumulated reward -1507.0
# accumulated reward -1508.0
# accumulated reward -1509.0
# accumulated reward -1510.0
# accumulated reward -1511.0
# accumulated reward -1512.0
# accumulated reward -1513.0
# accumulated reward -1514.0
# accumulated reward -1515.0
# accumulated reward -1516.0
# accumulated reward -1517.0
# accumulated reward -1518.0
# accumulated reward -1519.0
# accumulated reward -1520.0
# accumulated reward -1521.0
# accumulated reward -1522.0
# accumulated reward -1523.0
# accumulated reward -1524.0
# accumulated reward -1525.0
# accumulated reward -1526.0
# accumulated reward -1527.0
# accumulated reward -1528.0
# accumulated reward -1529.0
# accumulated reward -1530.0
# accumulated reward -1531.0
# accumulated reward -1532.0
# accumulated reward -1533.0
# accumulated reward -1534.0
# accumulated reward -1535.0
# accumulated reward -1536.0
# accumulated reward -1537.0
# accumulated reward -1538.0
# accumulated reward -1539.0
# accumulated reward -1540.0
# accumulated reward -1541.0
# accumulated reward -1542.0
# accumulated reward -1543.0
# accumulated reward -1544.0
# accumulated reward -1545.0
# accumulated reward -1546.0
# accumulated reward -1547.0
# accumulated reward -1548.0
# accumulated reward -1549.0
# accumulated reward -1550.0
# accumulated reward -1551.0
# accumulated reward -1552.0
# accumulated reward -1553.0
# accumulated reward -1554.0
# accumulated reward -1555.0
# accumulated reward -1556.0
# accumulated reward -1557.0
# accumulated reward -1558.0
# accumulated reward -1559.0
# accumulated reward -1560.0
# accumulated reward -1561.0
# accumulated reward -1562.0
# accumulated reward -1563.0
# accumulated reward -1564.0
# accumulated reward -1565.0
# accumulated reward -1566.0
# accumulated reward -1567.0
# accumulated reward -1568.0
# accumulated reward -1569.0
# accumulated reward -1570.0
# accumulated reward -1571.0
# accumulated reward -1572.0
# accumulated reward -1573.0
# accumulated reward -1574.0
# accumulated reward -1575.0
# accumulated reward -1576.0
# accumulated reward -1577.0
# accumulated reward -1578.0
# accumulated reward -1579.0
# accumulated reward -1580.0
# accumulated reward -1581.0
# accumulated reward -1582.0
# accumulated reward -1583.0
# accumulated reward -1584.0
# accumulated reward -1585.0
# accumulated reward -1586.0
# accumulated reward -1587.0
# accumulated reward -1588.0
# accumulated reward -1589.0
# accumulated reward -1590.0
# accumulated reward -1591.0
# accumulated reward -1592.0
# accumulated reward -1593.0
# accumulated reward -1594.0
# accumulated reward -1595.0
# accumulated reward -1596.0
# accumulated reward -1597.0
# accumulated reward -1598.0
# accumulated reward -1599.0
# accumulated reward -1600.0
# accumulated reward -1601.0
# accumulated reward -1602.0
# accumulated reward -1603.0
# accumulated reward -1604.0
# accumulated reward -1605.0
# accumulated reward -1606.0
# accumulated reward -1607.0
# accumulated reward -1608.0
# accumulated reward -1609.0
# accumulated reward -1610.0
# accumulated reward -1611.0
# accumulated reward -1612.0
# accumulated reward -1613.0
# accumulated reward -1614.0
# accumulated reward -1615.0
# accumulated reward -1616.0
# accumulated reward -1617.0
# accumulated reward -1618.0
# accumulated reward -1619.0
# accumulated reward -1620.0
# accumulated reward -1621.0
# accumulated reward -1622.0
# accumulated reward -1623.0
# accumulated reward -1624.0
# accumulated reward -1625.0
# accumulated reward -1626.0
# accumulated reward -1627.0
# accumulated reward -1628.0
# accumulated reward -1629.0
# accumulated reward -1630.0
# accumulated reward -1631.0
# accumulated reward -1632.0
# accumulated reward -1633.0
# accumulated reward -1634.0
# accumulated reward -1635.0
# accumulated reward -1636.0
# accumulated reward -1637.0
# accumulated reward -1638.0
# accumulated reward -1639.0
# accumulated reward -1640.0
# accumulated reward -1641.0
# accumulated reward -1642.0
# accumulated reward -1643.0
# accumulated reward -1644.0
# accumulated reward -1645.0
# accumulated reward -1646.0
# accumulated reward -1647.0
# accumulated reward -1648.0
# accumulated reward -1649.0
# accumulated reward -1650.0
# accumulated reward -1651.0
# accumulated reward -1652.0
# accumulated reward -1653.0
# accumulated reward -1654.0
# accumulated reward -1655.0
# accumulated reward -1656.0
# accumulated reward -1657.0
# accumulated reward -1658.0
# accumulated reward -1659.0
# accumulated reward -1660.0
# accumulated reward -1661.0
# accumulated reward -1662.0
# accumulated reward -1663.0
# accumulated reward -1664.0
# accumulated reward -1665.0
# accumulated reward -1666.0
# accumulated reward -1667.0
# accumulated reward -1668.0
# accumulated reward -1669.0
# accumulated reward -1670.0
# accumulated reward -1671.0
# accumulated reward -1672.0
# accumulated reward -1673.0
# accumulated reward -1674.0
# accumulated reward -1675.0
# accumulated reward -1676.0
# accumulated reward -1677.0
# accumulated reward -1678.0
# accumulated reward -1679.0
# accumulated reward -1680.0
# accumulated reward -1681.0
# accumulated reward -1682.0
# accumulated reward -1683.0
# accumulated reward -1684.0
# accumulated reward -1685.0
# accumulated reward -1686.0
# accumulated reward -1687.0
# accumulated reward -1688.0
# accumulated reward -1689.0
# accumulated reward -1690.0
# accumulated reward -1691.0
# accumulated reward -1692.0
# accumulated reward -1693.0
# accumulated reward -1694.0
# accumulated reward -1695.0
# accumulated reward -1696.0
# accumulated reward -1697.0
# accumulated reward -1698.0
# accumulated reward -1699.0
# accumulated reward -1700.0
# accumulated reward -1701.0
# accumulated reward -1702.0
# accumulated reward -1703.0
# accumulated reward -1704.0
# accumulated reward -1705.0
# accumulated reward -1706.0
# accumulated reward -1707.0
# accumulated reward -1708.0
# accumulated reward -1709.0
# accumulated reward -1710.0
# accumulated reward -1711.0
# accumulated reward -1712.0
# accumulated reward -1713.0
# accumulated reward -1714.0
# accumulated reward -1715.0
# accumulated reward -1716.0
# accumulated reward -1717.0
# accumulated reward -1718.0
# accumulated reward -1719.0
# accumulated reward -1720.0
# accumulated reward -1721.0
# accumulated reward -1722.0
# accumulated reward -1723.0
# accumulated reward -1724.0
# accumulated reward -1725.0
# accumulated reward -1726.0
# accumulated reward -1727.0
# accumulated reward -1728.0
# accumulated reward -1729.0
# accumulated reward -1730.0
# accumulated reward -1731.0
# accumulated reward -1732.0
# accumulated reward -1733.0
# accumulated reward -1734.0
# accumulated reward -1735.0
# accumulated reward -1736.0
# accumulated reward -1737.0
# accumulated reward -1738.0
# accumulated reward -1739.0
# accumulated reward -1740.0
# accumulated reward -1741.0
# accumulated reward -1742.0
# accumulated reward -1743.0
# accumulated reward -1744.0
# accumulated reward -1745.0
# accumulated reward -1746.0
# accumulated reward -1747.0
# accumulated reward -1748.0
# accumulated reward -1749.0
# accumulated reward -1750.0
# accumulated reward -1751.0
# accumulated reward -1752.0
# accumulated reward -1753.0
# accumulated reward -1754.0
# accumulated reward -1755.0
# accumulated reward -1756.0
# accumulated reward -1757.0
# accumulated reward -1758.0
# accumulated reward -1759.0
# accumulated reward -1760.0
# accumulated reward -1761.0
# accumulated reward -1762.0
# accumulated reward -1763.0
# accumulated reward -1764.0
# accumulated reward -1765.0
# accumulated reward -1766.0
# accumulated reward -1767.0
# accumulated reward -1768.0
# accumulated reward -1769.0
# accumulated reward -1770.0
# accumulated reward -1771.0
# accumulated reward -1772.0
# accumulated reward -1773.0
# accumulated reward -1774.0
# accumulated reward -1775.0
# accumulated reward -1776.0
# accumulated reward -1777.0
# accumulated reward -1778.0
# accumulated reward -1779.0
# accumulated reward -1780.0
# accumulated reward -1781.0
# accumulated reward -1782.0
# accumulated reward -1783.0
# accumulated reward -1784.0
# accumulated reward -1785.0
# accumulated reward -1786.0
# accumulated reward -1787.0
# accumulated reward -1788.0
# accumulated reward -1789.0
# accumulated reward -1790.0
# accumulated reward -1791.0
# accumulated reward -1792.0
# accumulated reward -1793.0
# accumulated reward -1794.0
# accumulated reward -1795.0
# accumulated reward -1796.0
# accumulated reward -1797.0
# accumulated reward -1798.0
# accumulated reward -1799.0
# accumulated reward -1800.0
# accumulated reward -1801.0
# accumulated reward -1802.0
# accumulated reward -1803.0
# accumulated reward -1804.0
# accumulated reward -1805.0
# accumulated reward -1806.0
# accumulated reward -1807.0
# accumulated reward -1808.0
# accumulated reward -1809.0
# accumulated reward -1810.0
# accumulated reward -1811.0
# accumulated reward -1812.0
# accumulated reward -1813.0
# accumulated reward -1814.0
# accumulated reward -1815.0
# accumulated reward -1816.0
# ...
# accumulated reward -38310.0
# accumulated reward -38311.0
# accumulated reward -38312.0
# accumulated reward -38313.0
# accumulated reward -38314.0
# accumulated reward -38315.0
# accumulated reward -38316.0
# accumulated reward -38317.0
# accumulated reward -38318.0
# accumulated reward -38319.0
# accumulated reward -38320.0
# accumulated reward -38321.0
# accumulated reward -38322.0
# accumulated reward -38323.0
# accumulated reward -38324.0
# accumulated reward -38325.0
# accumulated reward -38326.0
# accumulated reward -38327.0
# accumulated reward -38328.0
# accumulated reward -38329.0
# accumulated reward -38330.0
# accumulated reward -38331.0
# accumulated reward -38332.0
# accumulated reward -38333.0
# accumulated reward -38334.0
# accumulated reward -38335.0
# accumulated reward -38336.0
# accumulated reward -38337.0
# accumulated reward -38338.0
# accumulated reward -38339.0
# accumulated reward -38340.0
# accumulated reward -38341.0
# accumulated reward -38342.0
# accumulated reward -38343.0
# accumulated reward -38344.0
# accumulated reward -38345.0
# accumulated reward -38346.0
# accumulated reward -38347.0
# accumulated reward -38348.0
# accumulated reward -38349.0
# accumulated reward -38350.0
# accumulated reward -38351.0
# accumulated reward -38352.0
# accumulated reward -38353.0
# accumulated reward -38354.0
# accumulated reward -38355.0
# accumulated reward -38356.0
# accumulated reward -38357.0
# accumulated reward -38358.0
# accumulated reward -38359.0
# accumulated reward -38360.0
# accumulated reward -38361.0
# accumulated reward -38362.0
# accumulated reward -38363.0
# accumulated reward -38364.0
# accumulated reward -38365.0
# accumulated reward -38366.0
# accumulated reward -38367.0
# accumulated reward -38368.0
# accumulated reward -38369.0
# accumulated reward -38370.0
# accumulated reward -38371.0
# accumulated reward -38372.0
# accumulated reward -38373.0
# accumulated reward -38374.0
# accumulated reward -38375.0
# accumulated reward -38376.0
# accumulated reward -38377.0
# accumulated reward -38378.0
# accumulated reward -38379.0
# accumulated reward -38380.0
# accumulated reward -38381.0
# accumulated reward -38382.0
# accumulated reward -38383.0
# accumulated reward -38384.0
# accumulated reward -38385.0
# accumulated reward -38386.0
# accumulated reward -38387.0
# accumulated reward -38388.0
# accumulated reward -38389.0
# accumulated reward -38390.0
# accumulated reward -38391.0
# accumulated reward -38392.0
# accumulated reward -38393.0
# accumulated reward -38394.0
# accumulated reward -38395.0
# accumulated reward -38396.0
# accumulated reward -38397.0
# accumulated reward -38398.0
# accumulated reward -38399.0
# accumulated reward -38400.0
# accumulated reward -38401.0
# accumulated reward -38402.0
# accumulated reward -38403.0
# accumulated reward -38404.0
# accumulated reward -38405.0
# accumulated reward -38406.0
# accumulated reward -38407.0
# accumulated reward -38408.0
# accumulated reward -38409.0
# accumulated reward -38410.0
# accumulated reward -38411.0
# accumulated reward -38412.0
# accumulated reward -38413.0
# accumulated reward -38414.0
# accumulated reward -38415.0
# accumulated reward -38416.0
# accumulated reward -38417.0
# accumulated reward -38418.0
# accumulated reward -38419.0
# accumulated reward -38420.0
# accumulated reward -38421.0
# accumulated reward -38422.0
# accumulated reward -38423.0
# accumulated reward -38424.0
# accumulated reward -38425.0
# accumulated reward -38426.0
# accumulated reward -38427.0
# accumulated reward -38428.0
# accumulated reward -38429.0
# accumulated reward -38430.0
# accumulated reward -38431.0
# accumulated reward -38432.0
# accumulated reward -38433.0
# accumulated reward -38434.0
# accumulated reward -38435.0
# accumulated reward -38436.0
# accumulated reward -38437.0
# accumulated reward -38438.0
# accumulated reward -38439.0
# accumulated reward -38440.0
# accumulated reward -38441.0
# accumulated reward -38442.0
# accumulated reward -38443.0
# accumulated reward -38444.0
# accumulated reward -38445.0
# accumulated reward -38446.0
# accumulated reward -38447.0
# accumulated reward -38448.0
# accumulated reward -38449.0
# accumulated reward -38450.0
# accumulated reward -38451.0
# accumulated reward -38452.0
# accumulated reward -38453.0
# accumulated reward -38454.0
# accumulated reward -38455.0
# accumulated reward -38456.0
# accumulated reward -38457.0
# accumulated reward -38458.0
# accumulated reward -38459.0
# accumulated reward -38460.0
# accumulated reward -38461.0
# accumulated reward -38462.0
# accumulated reward -38463.0
# accumulated reward -38464.0
# accumulated reward -38465.0
# accumulated reward -38466.0
# accumulated reward -38467.0
# accumulated reward -38468.0
# accumulated reward -38469.0
# accumulated reward -38470.0
# accumulated reward -38471.0
# accumulated reward -38472.0
# accumulated reward -38473.0
# accumulated reward -38474.0
# accumulated reward -38475.0
# accumulated reward -38476.0
# accumulated reward -38477.0
# accumulated reward -38478.0
# accumulated reward -38479.0
# accumulated reward -38480.0
# accumulated reward -38481.0
# accumulated reward -38482.0
# accumulated reward -38483.0
# accumulated reward -38484.0
# accumulated reward -38485.0
# accumulated reward -38486.0
# accumulated reward -38487.0
# accumulated reward -38488.0
# accumulated reward -38489.0
# accumulated reward -38490.0
# accumulated reward -38491.0
# accumulated reward -38492.0
# accumulated reward -38493.0
# accumulated reward -38494.0
# accumulated reward -38495.0
# accumulated reward -38496.0
# accumulated reward -38497.0
# accumulated reward -38498.0
# accumulated reward -38499.0
# accumulated reward -38500.0
# accumulated reward -38501.0
# accumulated reward -38502.0
# accumulated reward -38503.0
# accumulated reward -38504.0
# accumulated reward -38505.0
# accumulated reward -38506.0
# accumulated reward -38507.0
# accumulated reward -38508.0
# accumulated reward -38509.0
# accumulated reward -38510.0
# accumulated reward -38511.0
# accumulated reward -38512.0
# accumulated reward -38513.0
# accumulated reward -38514.0
# accumulated reward -38515.0
# accumulated reward -38516.0
# accumulated reward -38517.0
# accumulated reward -38518.0
# accumulated reward -38519.0
# accumulated reward -38520.0
# accumulated reward -38521.0
# accumulated reward -38522.0
# accumulated reward -38523.0
# accumulated reward -38524.0
# accumulated reward -38525.0
# accumulated reward -38526.0
# accumulated reward -38527.0
# accumulated reward -38528.0
# accumulated reward -38529.0
# accumulated reward -38530.0
# accumulated reward -38531.0
# accumulated reward -38532.0
# accumulated reward -38533.0
# accumulated reward -38534.0
# accumulated reward -38535.0
# accumulated reward -38536.0
# accumulated reward -38537.0
# accumulated reward -38538.0
# accumulated reward -38539.0
# accumulated reward -38540.0
# accumulated reward -38541.0
# accumulated reward -38542.0
# accumulated reward -38543.0
# accumulated reward -38544.0
# accumulated reward -38545.0
# accumulated reward -38546.0
# accumulated reward -38547.0
# accumulated reward -38548.0
# accumulated reward -38549.0
# accumulated reward -38550.0
# accumulated reward -38551.0
# accumulated reward -38552.0
# accumulated reward -38553.0
# accumulated reward -38554.0
# accumulated reward -38555.0
# accumulated reward -38556.0
# accumulated reward -38557.0
# accumulated reward -38558.0
# accumulated reward -38559.0
# accumulated reward -38560.0
# accumulated reward -38561.0
# accumulated reward -38562.0
# accumulated reward -38563.0
# accumulated reward -38564.0
# accumulated reward -38565.0
# accumulated reward -38566.0
# accumulated reward -38567.0
# accumulated reward -38568.0
# accumulated reward -38569.0
# accumulated reward -38570.0
# accumulated reward -38571.0
# accumulated reward -38572.0
# accumulated reward -38573.0
# accumulated reward -38574.0
# accumulated reward -38575.0
# accumulated reward -38576.0
# accumulated reward -38577.0
# accumulated reward -38578.0
# accumulated reward -38579.0
# accumulated reward -38580.0
# accumulated reward -38581.0
# accumulated reward -38582.0
# accumulated reward -38583.0
# accumulated reward -38584.0
# accumulated reward -38585.0
# accumulated reward -38586.0
# accumulated reward -38587.0
# accumulated reward -38588.0
# accumulated reward -38589.0
# accumulated reward -38590.0
# accumulated reward -38591.0
# accumulated reward -38592.0
# accumulated reward -38593.0
# accumulated reward -38594.0
# accumulated reward -38595.0
# accumulated reward -38596.0
# accumulated reward -38597.0
# accumulated reward -38598.0
# accumulated reward -38599.0
# accumulated reward -38600.0
# accumulated reward -38601.0
# accumulated reward -38602.0
# accumulated reward -38603.0
# accumulated reward -38604.0
# accumulated reward -38605.0
# accumulated reward -38606.0
# accumulated reward -38607.0
# accumulated reward -38608.0
# accumulated reward -38609.0
# accumulated reward -38610.0
# accumulated reward -38611.0
# accumulated reward -38612.0
# accumulated reward -38613.0
# accumulated reward -38614.0
# accumulated reward -38615.0
# accumulated reward -38616.0
# accumulated reward -38617.0
# accumulated reward -38618.0
# accumulated reward -38619.0
# accumulated reward -38620.0
# accumulated reward -38621.0
# accumulated reward -38622.0
# accumulated reward -38623.0
# accumulated reward -38624.0
# accumulated reward -38625.0
# accumulated reward -38626.0
# accumulated reward -38627.0
# accumulated reward -38628.0
# accumulated reward -38629.0
# accumulated reward -38630.0
# accumulated reward -38631.0
# accumulated reward -38632.0
# accumulated reward -38633.0
# accumulated reward -38634.0
# accumulated reward -38635.0
# accumulated reward -38636.0
# accumulated reward -38637.0
# accumulated reward -38638.0
# accumulated reward -38639.0
# accumulated reward -38640.0
# accumulated reward -38641.0
# accumulated reward -38642.0
# accumulated reward -38643.0
# accumulated reward -38644.0
# accumulated reward -38645.0
# accumulated reward -38646.0
# accumulated reward -38647.0
# accumulated reward -38648.0
# accumulated reward -38649.0
# accumulated reward -38650.0
# accumulated reward -38651.0
# accumulated reward -38652.0
# accumulated reward -38653.0
# accumulated reward -38654.0
# accumulated reward -38655.0
# accumulated reward -38656.0
# accumulated reward -38657.0
# accumulated reward -38658.0
# accumulated reward -38659.0
# accumulated reward -38660.0
# accumulated reward -38661.0
# accumulated reward -38662.0
# accumulated reward -38663.0
# accumulated reward -38664.0
# accumulated reward -38665.0
# accumulated reward -38666.0
# accumulated reward -38667.0
# accumulated reward -38668.0
# accumulated reward -38669.0
# accumulated reward -38670.0
# accumulated reward -38671.0
# accumulated reward -38672.0
# accumulated reward -38673.0
# accumulated reward -38674.0
# accumulated reward -38675.0
# accumulated reward -38676.0
# accumulated reward -38677.0
# accumulated reward -38678.0
# accumulated reward -38679.0
# accumulated reward -38680.0
# accumulated reward -38681.0
# accumulated reward -38682.0
# accumulated reward -38683.0
# accumulated reward -38684.0
# accumulated reward -38685.0
# accumulated reward -38686.0
# accumulated reward -38687.0
# accumulated reward -38688.0
# accumulated reward -38689.0
# accumulated reward -38690.0
# accumulated reward -38691.0
# accumulated reward -38692.0
# accumulated reward -38693.0
# accumulated reward -38694.0
# accumulated reward -38695.0
# accumulated reward -38696.0
# accumulated reward -38697.0
# accumulated reward -38698.0
# accumulated reward -38699.0
# accumulated reward -38700.0
# accumulated reward -38701.0
# accumulated reward -38702.0
# accumulated reward -38703.0
# accumulated reward -38704.0
# accumulated reward -38705.0
# accumulated reward -38706.0
# accumulated reward -38707.0
# accumulated reward -38708.0
# accumulated reward -38709.0
# accumulated reward -38710.0
# accumulated reward -38711.0
# accumulated reward -38712.0
# accumulated reward -38713.0
# accumulated reward -38714.0
# accumulated reward -38715.0
# accumulated reward -38716.0
# accumulated reward -38717.0
# accumulated reward -38718.0
# accumulated reward -38719.0
# accumulated reward -38720.0
# accumulated reward -38721.0
# accumulated reward -38722.0
# accumulated reward -38723.0
# accumulated reward -38724.0
# accumulated reward -38725.0
# accumulated reward -38726.0
# accumulated reward -38727.0
# accumulated reward -38728.0
# accumulated reward -38729.0
# accumulated reward -38730.0
# accumulated reward -38731.0
# accumulated reward -38732.0
# accumulated reward -38733.0
# accumulated reward -38734.0
# accumulated reward -38735.0
# accumulated reward -38736.0
# accumulated reward -38737.0
# accumulated reward -38738.0
# accumulated reward -38739.0
# accumulated reward -38740.0
# accumulated reward -38741.0
# accumulated reward -38742.0
# accumulated reward -38743.0
# accumulated reward -38744.0
# accumulated reward -38745.0
# accumulated reward -38746.0
# accumulated reward -38747.0
# accumulated reward -38748.0
# accumulated reward -38749.0
# accumulated reward -38750.0
# accumulated reward -38751.0
# accumulated reward -38752.0
# accumulated reward -38753.0
# accumulated reward -38754.0
# accumulated reward -38755.0
# accumulated reward -38756.0
# accumulated reward -38757.0
# accumulated reward -38758.0
# accumulated reward -38759.0
# accumulated reward -38760.0
# accumulated reward -38761.0
# accumulated reward -38762.0
# accumulated reward -38763.0
# accumulated reward -38764.0
# accumulated reward -38765.0
# accumulated reward -38766.0
# accumulated reward -38767.0
# accumulated reward -38768.0
# accumulated reward -38769.0
# accumulated reward -38770.0
# accumulated reward -38771.0
# accumulated reward -38772.0
# accumulated reward -38773.0
# accumulated reward -38774.0
# accumulated reward -38775.0
# accumulated reward -38776.0
# accumulated reward -38777.0
# accumulated reward -38778.0
# accumulated reward -38779.0
# accumulated reward -38780.0
# accumulated reward -38781.0
# accumulated reward -38782.0
# accumulated reward -38783.0
# accumulated reward -38784.0
# accumulated reward -38785.0
# accumulated reward -38786.0
# accumulated reward -38787.0
# accumulated reward -38788.0
# accumulated reward -38789.0
# accumulated reward -38790.0
# accumulated reward -38791.0
# accumulated reward -38792.0
# accumulated reward -38793.0
# accumulated reward -38794.0
# accumulated reward -38795.0
# accumulated reward -38796.0
# accumulated reward -38797.0
# accumulated reward -38798.0
# accumulated reward -38799.0
# accumulated reward -38800.0
# accumulated reward -38801.0
# accumulated reward -38802.0
# accumulated reward -38803.0
# accumulated reward -38804.0
# accumulated reward -38805.0
# accumulated reward -38806.0
# accumulated reward -38807.0
# accumulated reward -38808.0
# accumulated reward -38809.0
# accumulated reward -38810.0
# accumulated reward -38811.0
# accumulated reward -38812.0
# accumulated reward -38813.0
# accumulated reward -38814.0
# accumulated reward -38815.0
# accumulated reward -38816.0
# accumulated reward -38817.0
# accumulated reward -38818.0
# accumulated reward -38819.0
# accumulated reward -38820.0
# accumulated reward -38821.0
# accumulated reward -38822.0
# accumulated reward -38823.0
# accumulated reward -38824.0
# accumulated reward -38825.0
# accumulated reward -38826.0
# accumulated reward -38827.0
# accumulated reward -38828.0
# accumulated reward -38829.0
# accumulated reward -38830.0
# accumulated reward -38831.0
# accumulated reward -38832.0
# accumulated reward -38833.0
# accumulated reward -38834.0
# accumulated reward -38835.0
# accumulated reward -38836.0
# accumulated reward -38837.0
# accumulated reward -38838.0
# accumulated reward -38839.0
# accumulated reward -38840.0
# accumulated reward -38841.0
# accumulated reward -38842.0
# accumulated reward -38843.0
# accumulated reward -38844.0
# accumulated reward -38845.0
# accumulated reward -38846.0
# accumulated reward -38847.0
# accumulated reward -38848.0
# accumulated reward -38849.0
# accumulated reward -38850.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6a3bc2659882> in <module>()
#      86                     episodeSum = 0
#      87                 break
# ---> 88             Q = tile.getQ(tile.getFeatures(state2), theta)
#      89             delta += gamma*np.max(Q)
#      90             theta += np.multiply((alpha*delta), tile.oneHotVector(F,action))
#
# <ipython-input-2-6a3bc2659882> in getFeatures(self, variables)
#      27         for i in range(self.numTilings):
#      28             for i2 in range(self.dim):
# ---> 29                 matrix[i,i2] = int(values[i2] / self.tileSize[i2] + i / self.numTilings)
#      30         for i in range(1,self.dim):
#      31             matrix[:,i] *= self.tilesPerTiling**i
#
# KeyboardInterrupt:
